# %%
import aptwrapper
import matplotlib.pyplot as plt

# %%
doc = aptwrapper.read('../primary_data/supp_sem_microscopy/2023-02-08 keio wt new samples for sem/doc3_sampleA_IR.axz')

# %%
aptwrapper.plot_map(doc.HeightMaps['IR Amplitude 3'])
