# %%
import matplotlib.pyplot as plt
import aptwrapper

# %%
doc = aptwrapper.read('../primary_data/supp_serial_sections/2024-05-31_TB012A_HA_section1A_maps.axz')

# %% [markdown]
# Line angle = 9.7°

# %%
aptwrapper.plot_map(doc.HeightMaps['IR Amplitude 2'])
